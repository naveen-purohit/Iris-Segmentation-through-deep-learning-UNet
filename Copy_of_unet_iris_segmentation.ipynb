# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# **Loading the training images and segmentation mask from google**

# %%
from keras.preprocessing.image import img_to_array
import numpy as np
import glob
import cv2


class dataProcess(object):
    def __init__(self, out_rows, out_cols,
                 npy_path = "/content/drive/MyDrive/segmentation", img_type = "bmp"):

        self.out_rows = out_rows
        self.out_cols = out_cols
        self.img_type = img_type
        self.npy_path = npy_path

    def load_train_data(self):
        print('-'*30)
        print('load train util images...')
        print('-'*30)
        imgs_train = np.load(self.npy_path+"/imgs_train.npy")
        imgs_mask_train = np.load(self.npy_path+"/imgs_mask_train.npy")
        print(imgs_train.shape)
        imgs_train = imgs_train.astype('float32')
        imgs_mask_train = imgs_mask_train.astype('float32')
        imgs_train /= 255
        imgs_mask_train /= 255

        imgs_mask_train[imgs_mask_train > 0.5] = 1
        imgs_mask_train[imgs_mask_train <= 0.5] = 0
        return imgs_train,imgs_mask_train


if __name__ == "__main__":
    pass

# %% [markdown]
# **implementing the U-Net neural network model using keras api and training the model**

# %%
from keras import optimizers
from keras.layers import Activation
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.layers import Conv2D, Input, UpSampling2D, MaxPooling2D,Concatenate
from keras import backend as K
import matplotlib.pyplot as plt
def load_data():
    mydata = dataProcess(240, 320)
    imgs_train, imgs_mask_train = mydata.load_train_data()
    return imgs_train, imgs_mask_train
###########################################################################
def conv_block(x, num_filters):
    x = Conv2D(num_filters, (3, 3),kernel_initializer = 'he_normal', padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, (3, 3),kernel_initializer = 'he_normal', padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x    



def create_model():
    num_filters = [64,128,256,512]
    inputs = Input(shape=[240, 320, 1])

    skip_x = []
    x = inputs
    ## Encoder
    for f in num_filters:
        x = conv_block(x, f)
        skip_x.append(x)
        x = MaxPooling2D((2, 2))(x)

    ## Bridge
    x = conv_block(x, 1024)

    num_filters.reverse()
    skip_x.reverse()
    ## Decoder
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2))(x)
        xs = skip_x[i]
        x = Concatenate()([x, xs])
        x = conv_block(x, f)

    ## Output
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)

    model = Model(inputs,x)

    model.summary()

    return model
###########################################################################

def train():
    model_path = "/content/drive/MyDrive/segmentation/"

    print("got model")
    model = create_model()
    print("loading data")
    imgs_train, imgs_mask_train = load_data()
    print("loading data done")

    opt = optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy"])

    model_checkpoint = ModelCheckpoint(model_path + 'unet_segmentation.hdf5', monitor='loss', verbose=1,
                                       save_best_only=True, save_weights_only=True, mode='auto', save_freq="epoch")
    print('Fitting model...')
    early_stop = EarlyStopping(monitor='loss', patience=10, verbose=0, mode='auto')
    lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=6, verbose=0, mode='min', cooldown=0,
                           min_lr=0.000001)
    history=model.fit(imgs_train, imgs_mask_train, batch_size=2, epochs=20, verbose=1, validation_split=0.2,
                        shuffle=True,
                        callbacks=[model_checkpoint,lr, early_stop])
     # summarize history for accuracy
    #for key in history.history.keys():
     #  print(key)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(model_path + "accuracy.png")
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig(model_path + "loss.png")
    plt.show()
    

if __name__ == '__main__':
    train()
    K.clear_session()
# Out:
# got model
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 240, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 320, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 240, 320, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 240, 320, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 320, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 320, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 320, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 160, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 120, 160, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 120, 160, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 120, 160, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 160, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 160, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 160, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 80, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 60, 80, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 60, 80, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 60, 80, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 80, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 60, 80, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 80, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 30, 40, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 30, 40, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 30, 40, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 30, 40, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 40, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 40, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 30, 40, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 15, 20, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 15, 20, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 15, 20, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15, 20, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 20, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15, 20, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15, 20, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 30, 40, 1024) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 40, 1536) 0           up_sampling2d[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 40, 512)  7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 40, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 40, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 40, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 30, 40, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 40, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 60, 80, 512)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 80, 768)  0           up_sampling2d_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 80, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 80, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 80, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 80, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 80, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 80, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 120, 160, 256 0           activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 160, 384 0           up_sampling2d_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 160, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 160, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 120, 160, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 160, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 120, 160, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 120, 160, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 240, 320, 128 0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 320, 192 0           up_sampling2d_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 320, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 320, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 240, 320, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 320, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 240, 320, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 240, 320, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 320, 1)  65          activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 240, 320, 1)  0           conv2d_18[0][0]
# ==================================================================================================
# Total params: 31,401,345
# Trainable params: 31,389,569
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# loading data
# ------------------------------
# load train util images...
# ------------------------------
# (2240, 240, 320, 1)
# loading data done
# Fitting model...
# Epoch 1/20
# 896/896 [==============================] - 229s 198ms/step - loss: 0.1092 - accuracy: 0.9605 - val_loss: 0.0558 - val_accuracy: 0.9795
#
# Epoch 00001: loss improved from inf to 0.06948, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 2/20
# 896/896 [==============================] - 187s 209ms/step - loss: 0.0407 - accuracy: 0.9843 - val_loss: 0.1413 - val_accuracy: 0.9578
#
# Epoch 00002: loss improved from 0.06948 to 0.04022, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 3/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0399 - accuracy: 0.9841 - val_loss: 0.0473 - val_accuracy: 0.9805
#
# Epoch 00003: loss improved from 0.04022 to 0.03736, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 4/20
# 896/896 [==============================] - 194s 216ms/step - loss: 0.0335 - accuracy: 0.9861 - val_loss: 0.0445 - val_accuracy: 0.9824
#
# Epoch 00004: loss improved from 0.03736 to 0.03380, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 5/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0310 - accuracy: 0.9868 - val_loss: 0.0456 - val_accuracy: 0.9820
#
# Epoch 00005: loss improved from 0.03380 to 0.03067, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 6/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0310 - accuracy: 0.9869 - val_loss: 0.0422 - val_accuracy: 0.9828
#
# Epoch 00006: loss improved from 0.03067 to 0.03045, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 7/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0284 - accuracy: 0.9879 - val_loss: 0.0663 - val_accuracy: 0.9782
#
# Epoch 00007: loss improved from 0.03045 to 0.02887, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 8/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0310 - accuracy: 0.9869 - val_loss: 0.0413 - val_accuracy: 0.9838
#
# Epoch 00008: loss did not improve from 0.02887
# Epoch 9/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0270 - accuracy: 0.9883 - val_loss: 0.0414 - val_accuracy: 0.9833
#
# Epoch 00009: loss improved from 0.02887 to 0.02731, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 10/20
# 896/896 [==============================] - 194s 217ms/step - loss: 0.0295 - accuracy: 0.9876 - val_loss: 0.0430 - val_accuracy: 0.9834
#
# Epoch 00010: loss did not improve from 0.02731
# Epoch 11/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.0422 - val_accuracy: 0.9836
#
# Epoch 00011: loss improved from 0.02731 to 0.02571, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 12/20
# 896/896 [==============================] - 194s 217ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.0456 - val_accuracy: 0.9822
#
# Epoch 00012: loss did not improve from 0.02571
# Epoch 13/20
# 896/896 [==============================] - 195s 217ms/step - loss: 0.0241 - accuracy: 0.9895 - val_loss: 0.0427 - val_accuracy: 0.9836
#
# Epoch 00013: loss improved from 0.02571 to 0.02459, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 14/20
# 896/896 [==============================] - 194s 217ms/step - loss: 0.0239 - accuracy: 0.9897 - val_loss: 0.0446 - val_accuracy: 0.9830
#
# Epoch 00014: loss did not improve from 0.02459
# Epoch 15/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0234 - accuracy: 0.9898 - val_loss: 0.0487 - val_accuracy: 0.9826
#
# Epoch 00015: loss improved from 0.02459 to 0.02334, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 16/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0235 - accuracy: 0.9898 - val_loss: 0.0443 - val_accuracy: 0.9835
#
# Epoch 00016: loss did not improve from 0.02334
# Epoch 17/20
# 896/896 [==============================] - 194s 217ms/step - loss: 0.0214 - accuracy: 0.9907 - val_loss: 0.0467 - val_accuracy: 0.9829
#
# Epoch 00017: loss improved from 0.02334 to 0.02153, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 18/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0202 - accuracy: 0.9911 - val_loss: 0.0492 - val_accuracy: 0.9831
#
# Epoch 00018: loss improved from 0.02153 to 0.02066, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5
# Epoch 19/20
# 896/896 [==============================] - 194s 217ms/step - loss: 0.0210 - accuracy: 0.9909 - val_loss: 0.0501 - val_accuracy: 0.9833
#
# Epoch 00019: loss did not improve from 0.02066
# Epoch 20/20
# 896/896 [==============================] - 188s 210ms/step - loss: 0.0193 - accuracy: 0.9916 - val_loss: 0.0458 - val_accuracy: 0.9838
#
# Epoch 00020: loss improved from 0.02066 to 0.02030, saving model to /content/drive/MyDrive/segmentation/unet_segmentation.hdf5

# %% [markdown]
# **testing the trained model and predicting the segmentation mask of iris images**

# %%
from keras.preprocessing.image import array_to_img
path="/content/drive/MyDrive/segmentation"
data_path = path+"/"+"test"
    
model_path = path
print(model_path)
print(data_path)

img_type = "bmp"

imgs = glob.glob(data_path + "/*." + img_type)
print(imgs)
# import the model
model = create_model()

# load the model
model.load_weights(model_path + '/unet_segmentation.hdf5')
i=1
for imgname in imgs:
  image_rgb = (np.array(cv2.imread(imgname, 0))).astype(np.float32)
  image = np.expand_dims(image_rgb, axis=-1) / 255
  net_in = np.zeros((1, 240, 320, 1), dtype=np.float32)
  net_in[0] = image
  imgs_mask_test = model.predict(net_in)[0]
  img = imgs_mask_test
  img=img>0.5
  img=img*255.0
  img = array_to_img(img)
  img.save(model_path+"/"+"predicted"+"/"+str(i)+".tiff")
  i=i+1;
K.clear_session()
# Out:
# /content/drive/MyDrive/segmentation
# /content/drive/MyDrive/segmentation/test
# ['/content/drive/MyDrive/segmentation/test/073_05_L.bmp', '/content/drive/MyDrive/segmentation/test/073_09_R.bmp', '/content/drive/MyDrive/segmentation/test/073_02_L.bmp', '/content/drive/MyDrive/segmentation/test/073_06_R.bmp', '/content/drive/MyDrive/segmentation/test/073_07_R.bmp', '/content/drive/MyDrive/segmentation/test/073_03_L.bmp', '/content/drive/MyDrive/segmentation/test/073_08_R.bmp', '/content/drive/MyDrive/segmentation/test/073_10_R.bmp', '/content/drive/MyDrive/segmentation/test/073_04_L.bmp']
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 240, 320, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 320, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 240, 320, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 240, 320, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 320, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 320, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 320, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 160, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 120, 160, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 120, 160, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 120, 160, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 160, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 160, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 160, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 80, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 60, 80, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 60, 80, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 60, 80, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 80, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 60, 80, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 60, 80, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 30, 40, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 30, 40, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 30, 40, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 30, 40, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 40, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 40, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 30, 40, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 15, 20, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 15, 20, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 15, 20, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15, 20, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 20, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15, 20, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15, 20, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 30, 40, 1024) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 40, 1536) 0           up_sampling2d[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 40, 512)  7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 40, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 40, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 40, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 30, 40, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 30, 40, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 60, 80, 512)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 80, 768)  0           up_sampling2d_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 80, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 80, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 80, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 80, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 80, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 80, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 120, 160, 256 0           activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 160, 384 0           up_sampling2d_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 160, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 160, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 120, 160, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 160, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 120, 160, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 120, 160, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 240, 320, 128 0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 320, 192 0           up_sampling2d_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 320, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 320, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 240, 320, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 320, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 240, 320, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 240, 320, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 320, 1)  65          activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 240, 320, 1)  0           conv2d_18[0][0]
# ==================================================================================================
# Total params: 31,401,345
# Trainable params: 31,389,569
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
